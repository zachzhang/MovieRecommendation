# %%
from imdb import IMDb
ia = IMDb()

the_matrix = ia.get_movie('0133093')
print the_matrix['director']

for person in ia.search_person('Mel Gibson'):
        print person.personID, person['name']
# Out:
# [<Person id:0905154[http] name:_Wachowski, Lana_>, <Person id:0905152[http] name:_Wachowski, Lilly_>]
# 0000154 Mel Gibson
# 0317112 Mel Gibson
# 3323885 Adam Taylor
# 2153167 Mel Gibson
# 6709224 Mel Gibson
# 2800055 Mel Gibson
# 0316945 Donal Gibson
# 2106809 Raquel Gibson
# 0316878 Cal Gibson
# 0317195 Terel Gibson
# 8026448 Hazel Gibson
# 7699405 Jamel Gibson
# 7133936 Jamel Gibson
# 3912400 Jamel Gibson
# 0316950 E.L. Gibson
# 2988370 Mal Gibson
# 0316932 Dean Paul Gibson
# 0316887 Cathy Mickel Gibson
# 4047961 Noel Gibson
# 2798174 Daniel Gibson

# %%
s_result = ia.search_movie('Toy Story (1995)')

# Print the long imdb canonical title and movieID of the results.
print type(s_result[0])

#for item in s_result:
#   print item['long imdb canonical title'], item.movieID
# Out:
# <class 'imdb.Movie.Movie'>

# %%
import pandas as pd
import numpy as np

movieMap = pd.read_csv('ml-latest-small/movies.csv')
movies = movieMap['title']

ia = IMDb()

all_movie_data = []
the_matrix = ia.get_movie('0133093')
keys = the_matrix.keys()

for movie in movies:
    
    movie_search_name = movie
    s_result = []
    while len(s_result) == 0 and len(movie_search_name) > 0:
        
        s_result = ia.search_movie(movie_search_name)
        movie_search_name = movie_search_name.rsplit(' ', 1)[0]
    
    try:
        
        print movie
        
        #s_results = ia.search_movie(movie_search_name)

        imdb_id = s_results[0].movieID

        imdb_movie = ia.get_movie(imdb_id)

        features=[]

        for key in keys:
            
            if  key in imdb_movie.keys():
                features.append(imdb_movie[key])
            else:
                features.append(np.nan)
                
        all_movie_data.append( features)
            
    except:
        pass

    
all_movie_data = pd.DataFrame(all_movie_data ,columns = keys)
all_movie_data['movie'] = movies

all_movie_data.to_csv('movieData.csv')
# Out:
# Toy Story (1995)
# Jumanji (1995)
# Grumpier Old Men (1995)
# Waiting to Exhale (1995)
# Father of the Bride Part II (1995)

# %%
all_movie_data.iloc[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /Library/Python/2.7/site-packages/IPython/core/formatters.pyc in __call__(self, obj)
#     697                 type_pprinters=self.type_printers,
#     698                 deferred_pprinters=self.deferred_printers)
# --> 699             printer.pretty(obj)
#     700             printer.flush()
#     701             return stream.getvalue()
#
# /Library/Python/2.7/site-packages/IPython/lib/pretty.pyc in pretty(self, obj)
#     381                             if callable(meth):
#     382                                 return meth(obj, self, cycle)
# --> 383             return _default_pprint(obj, self, cycle)
#     384         finally:
#     385             self.end_group()
#
# /Library/Python/2.7/site-packages/IPython/lib/pretty.pyc in _default_pprint(obj, p, cycle)
#     501     if _safe_getattr(klass, '__repr__', None) not in _baseclass_reprs:
#     502         # A user-provided repr. Find newlines and replace them with p.break_()
# --> 503         _repr_pprint(obj, p, cycle)
#     504         return
#     505     p.begin_group(1, '<')
#
# /Library/Python/2.7/site-packages/IPython/lib/pretty.pyc in _repr_pprint(obj, p, cycle)
#     692     """A pprint that just redirects to the normal repr function."""
#     693     # Find newlines and replace them with p.break_()
# --> 694     output = repr(obj)
#     695     for idx,output_line in enumerate(output.splitlines()):
#     696         if idx:
#
# /usr/local/lib/python2.7/site-packages/pandas/core/base.pyc in __repr__(self)
#      65         Yields Bytestring in Py2, Unicode String in py3.
#      66         """
# ---> 67         return str(self)
#      68
#      69
#
# /usr/local/lib/python2.7/site-packages/pandas/core/base.pyc in __str__(self)
#      45         if compat.PY3:
#      46             return self.__unicode__()
# ---> 47         return self.__bytes__()
#      48
#      49     def __bytes__(self):
#
# /usr/local/lib/python2.7/site-packages/pandas/core/base.pyc in __bytes__(self)
#      57
#      58         encoding = get_option("display.encoding")
# ---> 59         return self.__unicode__().encode(encoding, 'replace')
#      60
#      61     def __repr__(self):
#
# /usr/local/lib/python2.7/site-packages/pandas/core/series.pyc in __unicode__(self)
#     982
#     983         self.to_string(buf=buf, name=self.name, dtype=self.dtype,
# --> 984                        max_rows=max_rows)
#     985         result = buf.getvalue()
#     986
#
# /usr/local/lib/python2.7/site-packages/pandas/core/series.pyc in to_string(self, buf, na_rep, float_format, header, index, length, dtype, name, max_rows)
#    1023         the_repr = self._get_repr(float_format=float_format, na_rep=na_rep,
#    1024                                   header=header, index=index, length=length,
# -> 1025                                   dtype=dtype, name=name, max_rows=max_rows)
#    1026
#    1027         # catch contract violations
#
# /usr/local/lib/python2.7/site-packages/pandas/core/series.pyc in _get_repr(self, name, header, index, length, dtype, na_rep, float_format, max_rows)
#    1051                                         float_format=float_format,
#    1052                                         max_rows=max_rows)
# -> 1053         result = formatter.to_string()
#    1054
#    1055         # TODO: following check prob. not neces.
#
# /usr/local/lib/python2.7/site-packages/pandas/formats/format.pyc in to_string(self)
#     223
#     224         fmt_index, have_header = self._get_formatted_index()
# --> 225         fmt_values = self._get_formatted_values()
#     226
#     227         if self.truncate_v:
#
# /usr/local/lib/python2.7/site-packages/pandas/formats/format.pyc in _get_formatted_values(self)
#     213     def _get_formatted_values(self):
#     214         return format_array(self.tr_series._values, None,
# --> 215                             float_format=self.float_format, na_rep=self.na_rep)
#     216
#     217     def to_string(self):
#
# /usr/local/lib/python2.7/site-packages/pandas/formats/format.pyc in format_array(values, formatter, float_format, na_rep, digits, space, justify, decimal)
#    2005                         space=space, justify=justify, decimal=decimal)
#    2006
# -> 2007     return fmt_obj.get_result()
#    2008
#    2009
#
# /usr/local/lib/python2.7/site-packages/pandas/formats/format.pyc in get_result(self)
#    2024
#    2025     def get_result(self):
# -> 2026         fmt_values = self._format_strings()
#    2027         return _make_fixed_width(fmt_values, self.justify)
#    2028
#
# /usr/local/lib/python2.7/site-packages/pandas/formats/format.pyc in _format_strings(self)
#    2063         for i, v in enumerate(vals):
#    2064             if not is_float[i] and leading_space:
# -> 2065                 fmt_values.append(' %s' % _format(v))
#    2066             elif is_float[i]:
#    2067                 fmt_values.append(float_format(v))
#
# /usr/local/lib/python2.7/site-packages/pandas/formats/format.pyc in _format(x)
#    2051             else:
#    2052                 # object dtype
# -> 2053                 return '%s' % formatter(x)
#    2054
#    2055         vals = self.values
#
# /usr/local/lib/python2.7/site-packages/pandas/formats/format.pyc in <lambda>(x)
#    2038         formatter = (
#    2039             self.formatter if self.formatter is not None else
# -> 2040             (lambda x: pprint_thing(x, escape_chars=('\t', '\r', '\n'))))
#    2041
#    2042         def _format(x):
#
# /usr/local/lib/python2.7/site-packages/pandas/formats/printing.pyc in pprint_thing(thing, _nest_lvl, escape_chars, default_escapes, quote_strings, max_seq_items)
#     218         result = _pprint_seq(thing, _nest_lvl, escape_chars=escape_chars,
#     219                              quote_strings=quote_strings,
# --> 220                              max_seq_items=max_seq_items)
#     221     elif isinstance(thing, compat.string_types) and quote_strings:
#     222         if compat.PY3:
#
# /usr/local/lib/python2.7/site-packages/pandas/formats/printing.pyc in _pprint_seq(seq, _nest_lvl, max_seq_items, **kwds)
#     115     for i in range(min(nitems, len(seq))):  # handle sets, no slicing
#     116         r.append(pprint_thing(
# --> 117             next(s), _nest_lvl + 1, max_seq_items=max_seq_items, **kwds))
#     118     body = ", ".join(r)
#     119
#
# /usr/local/lib/python2.7/site-packages/pandas/formats/printing.pyc in pprint_thing(thing, _nest_lvl, escape_chars, default_escapes, quote_strings, max_seq_items)
#     218         result = _pprint_seq(thing, _nest_lvl, escape_chars=escape_chars,
#     219                              quote_strings=quote_strings,
# --> 220                              max_seq_items=max_seq_items)
#     221     elif isinstance(thing, compat.string_types) and quote_strings:
#     222         if compat.PY3:
#
# /usr/local/lib/python2.7/site-packages/pandas/formats/printing.pyc in _pprint_seq(seq, _nest_lvl, max_seq_items, **kwds)
#     115     for i in range(min(nitems, len(seq))):  # handle sets, no slicing
#     116         r.append(pprint_thing(
# --> 117             next(s), _nest_lvl + 1, max_seq_items=max_seq_items, **kwds))
#     118     body = ", ".join(r)
#     119
#
# /usr/local/lib/python2.7/site-packages/imdb/utils.pyc in __getitem__(self, key)
#    1467         # Handle key aliases.
#    1468         key = self.keys_alias.get(key, key)
# -> 1469         rawData = self.data[key]
#    1470         if key in self.keys_tomodify and \
#    1471                 self.modFunct not in (None, modNull):
#
# KeyError: 0

# %%
X = pd.read_csv('movieData.csv')

# %%
X.iloc[4]
# Out:
# Unnamed: 0                                                                          4
# music department                    [<Person id:0214010[http] name:_DeCrescent, Sa...
# sound crew                          [<Person id:0026751[http] name:_Anderson, Geor...
# camera and electrical department    [<Person id:1064134[http] name:_Bertram, John_...
# distributors                        [<Company id:0044279[http] name:_Buena Vista P...
# rating                                                                            5.9
# runtimes                                                                     [u'106']
# costume designer                      [<Person id:0364672[http] name:_Harris, Enid_>]
# make up                             [<Person id:0136167[http] name:_Ananda, Ma Kal...
# year                                                                             1995
# production design                   [<Person id:0220984[http] name:_DeScenna, Lind...
# miscellaneous crew                  [<Person id:0017656[http] name:_Aldrich, Adell...
# color info                                                         [u'(Technicolor)']
# casting department                  [<Person id:0364456[http] name:_Harris, Barbar...
# languages                                                                [u'English']
# votes                                                                           27083
# producer                            [<Person id:0062071[http] name:_Baum, Carol_>,...
# title                                                     Father of the Bride Part II
# mpaa                                Rated PG for some mild language and thematic e...
# assistant director                  [<Person id:0088692[http] name:_Block, Bruce A...
# writer                              [<Person id:0352443[http] name:_Hackett, Alber...
# production manager                  [<Person id:0114454[http] name:_Brown, R. Anth...
# casting director                    [<Person id:0338528[http] name:_Greenberg, Jef...
# visual effects                      [<Person id:0421117[http] name:_Jennings, Bria...
# top 250 rank                                                                      NaN
# set decoration                        [<Person id:0568467[http] name:_McElvin, Ric_>]
# editor                              [<Person id:0003146[http] name:_Bernardi, Adam...
# certificates                        [u'Argentina:Atp', u'Australia:G', u'Finland:S...
# costume department                  [<Person id:0030719[http] name:_Antablin, Meli...
# country codes                                                                 [u'us']
#                                                           ...
# special effects department          [<Person id:0227908[http] name:_Dion, David_>,...
# special effects companies           [<Company id:0040822[http] name:_Lebensfeld Pr...
# sound mix                                                [u'Dolby', u'Dolby Digital']
# location management                 [<Person id:0198000[http] name:_Dallago, Rick_...
# genres                                             [u'Comedy', u'Family', u'Romance']
# director                            [<Person id:0796124[http] name:_Shyer, Charles_>]
# stunt performer                     [<Person id:0102334[http] name:_Boyle, Shelley...
# miscellaneous companies             [<Company id:0296111[http] name:_Direct Tools ...
# cinematographer                     [<Person id:0204567[http] name:_Davis, Elliot_...
# art direction                        [<Person id:0660272[http] name:_Papalia, Greg_>]
# akas                                [u'El padre de la novia Parte II::Mexico (imdb...
# aspect ratio                                                                 1.85 : 1
# production companies                [<Company id:0005929[http] name:_Sandollar Pro...
# kind                                                                            movie
# art department                      [<Person id:0027403[http] name:_Anderson, Sam_...
# countries                                                                    [u'USA']
# transportation department           [<Person id:0490232[http] name:_Latina, Stephe...
# plot outline                        George Banks must deal not only with the pregn...
# plot                                [u'In this sequel to "Father of the Bride", Ge...
# cast                                [<Person id:0000188[http] name:_Martin, Steve_...
# animation department                                                              NaN
# original music                      [<Person id:0006293[http] name:_Silvestri, Ala...
# editorial department                [<Person id:0003146[http] name:_Bernardi, Adam...
# canonical title                                           Father of the Bride Part II
# long imdb title                                    Father of the Bride Part II (1995)
# long imdb canonical title                          Father of the Bride Part II (1995)
# smart canonical title                                     Father of the Bride Part II
# smart long imdb canonical title                    Father of the Bride Part II (1995)
# full-size cover url                 https://images-na.ssl-images-amazon.com/images...
# movie                                              Father of the Bride Part II (1995)
# Name: 4, dtype: object

# %%
# Out:
# ['movie', u'music department', 'sound crew', 'camera and electrical department', u'distributors', 'rating', 'runtimes', 'costume designer', 'make up', 'year', 'production design', 'miscellaneous crew', 'color info', u'casting department', 'languages', 'votes', 'producer', 'title', 'mpaa', 'assistant director', 'writer', 'production manager', 'casting director', 'visual effects', 'top 250 rank', 'set decoration', 'editor', 'certificates', u'costume department', 'country codes', 'language codes', 'cover url', u'special effects department', 'special effects companies', 'sound mix', u'location management', 'genres', 'director', 'stunt performer', 'miscellaneous companies', 'cinematographer', 'art direction', 'akas', 'aspect ratio', u'production companies', 'kind', u'art department', 'countries', u'transportation department', 'plot outline', 'plot', 'cast', u'animation department', 'original music', u'editorial department', 'canonical title', 'long imdb title', 'long imdb canonical title', 'smart canonical title', 'smart long imdb canonical title', 'full-size cover url']

# %%
the_matrix = ia.get_movie('0133093')
columns =  ['movie'] + the_matrix.keys()

print len(the_matrix.keys())
# Out:
# 60

# %%
import numpy as np

# %%
np.nan
# Out:
# nan
